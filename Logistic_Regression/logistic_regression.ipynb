# %% [markdown]
# ## Logistic Regression
#
# For Logistic Regression, we have a ``LogisticRegression`` class provided by sklearn's ``linearmodel``.
# We can initialize the class, train and test the model.
#
# We can also see the probability of the prediction using ``predict_proba`` function. It provides the probability of prediction being closer to 1 and 0. For example, if you have two classes (0 and 1), it might say there's a 20% chance it's 0 and an 80% chance it's 1.
#
# How does Logistic Regression works?
# 1. It takes features and labels of the training data.
# 2. It fits the data in a linear model (weights and biases).
# 3. Instead of providing the result, it gives a logistic result.

# %%
# Importing the required modules
import pandas as pd

# %%
# importing dataset
data = pd.read_csv('insurance_data.csv')
data.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
# plotting the graph to get an overview of the data
from matplotlib import pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10, 4))
plt.scatter(data['age'], data['bought_insurance'], marker='*', color='orange')

# %% [markdown]
# We can see that the data is distributed such that the person whose age is smaller is likely to buy insurance and vice versa. So, we can go for the logistic regression.

# %%
from sklearn.linear_model import LogisticRegression

# Creating object of LogisticRegression class
model = LogisticRegression()

# %%
# Splitting training and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(data[['age']], data[['bought_insurance']], train_size=0.7)

# %%
# Training the model
model.fit(X_train, Y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Predicting the result
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([1, 1, 0, 1, 0, 1, 1, 1, 0])

# %%
Y_test
# Out:
#     bought_insurance
# 17                 1
# 15                 1
# 10                 0
# 5                  1
# 19                 0
# 8                  1
# 2                  1
# 25                 1
# 21                 0

# %%
# Checking the score of the model
model.score(X_test,Y_test)
# Out:
# 1.0
